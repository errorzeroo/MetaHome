# %%
import pandas as pd

df = pd.read_csv("./scaleResult3.csv")
df.head()
# Out:
#                     address      park  hospital    subway       bus   parking  \
# 0     서울특별시 강남구 강남대로120길 52  0.367613  0.932091  0.925364  0.800231  0.767795
# 1   서울특별시 강남구 강남대로124길 70-1  0.486125  0.888149  0.904531  0.802540  0.689226
# 2  서울특별시 강남구 강남대로162길 27-11  0.575579  0.858855  0.905542  0.867206  0.782186
# 3         서울특별시 강남구 개포로 264  0.586353  0.806924  0.815736  0.881640  0.825360
# 4       서울특별시 강남구 개포로109길 5  0.526934  0.998668  0.914239  0.945727  0.858032
#
#     element    middle      high  hospitalcount homeKind
# 0  0.892248  0.319258  0.616672       0.109293    다가구주택
# 1  0.747287  0.344850  0.532612       0.091415    다가구주택
# 2  0.669767  0.739603  0.816882       0.084331    다가구주택
# 3  0.871318  0.561740  0.866411       0.343903      아파트
# 4  0.750388  0.825976  0.803279       0.301906      아파트

# %%
df['homeKind'].isnull().sum()
# Out:
# 250

# %%
len(df)
# Out:
# 5234

# %%
df = df.dropna(subset=['homeKind'])

# %%
print(df['homeKind'].isnull().sum())  # 0이면 성공적으로 제거됨
# Out:
# 0

# %%
df
# Out:
#                        address      park  hospital    subway       bus  \
# 0        서울특별시 강남구 강남대로120길 52  0.367613  0.932091  0.925364  0.800231
# 1      서울특별시 강남구 강남대로124길 70-1  0.486125  0.888149  0.904531  0.802540
# 2     서울특별시 강남구 강남대로162길 27-11  0.575579  0.858855  0.905542  0.867206
# 3            서울특별시 강남구 개포로 264  0.586353  0.806924  0.815736  0.881640
# 4          서울특별시 강남구 개포로109길 5  0.526934  0.998668  0.914239  0.945727
# ...                        ...       ...       ...       ...       ...
# 5228      서울특별시 중랑구 중랑천로18길 14  0.454456  0.724368  0.807039  0.864896
# 5229       서울특별시 중랑구 중랑천로18길 8  0.459680  0.699068  0.802994  0.855081
# 5231      서울특별시 중랑구 중랑천로20길 39  0.372511  0.725699  0.851942  0.733834
# 5232    서울특별시 중랑구 중랑천로24길 18-7  0.374143  0.697736  0.849717  0.727483
# 5233       서울특별시 중랑구 중랑천로2길 36  0.607248  0.693742  0.812298  0.937644
#
#        parking   element    middle      high  hospitalcount homeKind
# 0     0.767795  0.892248  0.319258  0.616672       0.109293    다가구주택
# 1     0.689226  0.747287  0.344850  0.532612       0.091415    다가구주택
# 2     0.782186  0.669767  0.739603  0.816882       0.084331    다가구주택
# 3     0.825360  0.871318  0.561740  0.866411       0.343903      아파트
# 4     0.858032  0.750388  0.825976  0.803279       0.301906      아파트
# ...        ...       ...       ...       ...            ...      ...
# 5228  0.738623  0.500000  0.415867  0.643181       0.651375    다세대주택
# 5229  0.745624  0.495349  0.400512  0.648064       0.646146    다세대주택
# 5231  0.641774  0.325581  0.523353  0.581095       0.656940    다세대주택
# 5232  0.643329  0.331008  0.512476  0.576561       0.655422    다세대주택
# 5233  0.733956  0.713178  0.672425  0.777468       0.658121    다세대주택
#
# [4984 rows x 11 columns]

# %%
len(df)
# Out:
# 4984

# %%
df.to_csv("scaleResult3.csv", index=False, encoding="utf-8-sig")
